# %%
#!pip install selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

# Configuración específica para Colab
chrome_options = Options()
chrome_options.add_argument('--headless')  # Ejecución sin interfaz gráfica
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Inicializar el driver de Selenium
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.aa.com/es-mx/vuelos?c=SEM%7CGOOG%7Calways_on%7CMKT%7CLAM%7CTXT%7Camerican%20airlines%7CMX_MCLA_MKT_Google_Brand_X_Mexico_National_ES_X$$&gad_source=1&gclid=Cj0KCQjwvb-zBhCmARIsAAfUI2tA1kC35ygd1ShwDBf-rMSX9F7nfO1ckMRtcopYsXKIyzmvVOfFwX8aAm3nEALw_wcB&gclsrc=aw.ds")

# Mes que queremos seleccionar
month = "noviembre 2024"

# Código original para seleccionar el mes
driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div/div/div[1]/div/div/div/div/label[1]").click()


mon = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/div[3]/div[2]/p")
if mon.text == month:
    # Captura de pantalla del mes seleccionado
    driver.save_screenshot("mes_seleccionado.png")
else:
    driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/button[2]/span").click()
    # Captura de pantalla después de avanzar el mes
    driver.save_screenshot("avanzar_mes.png")

# Espera para visualizar la pantalla antes de cerrar
time.sleep(2)

# Cerrar el navegador al finalizar
driver.quit()

# %%
#!pip install selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

# Configuración específica para Colab
chrome_options = Options()
chrome_options.add_argument('--headless')  # Ejecución sin interfaz gráfica
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Inicializar el driver de Selenium
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.aa.com/es-mx/vuelos?c=SEM%7CGOOG%7Calways_on%7CMKT%7CLAM%7CTXT%7Camerican%20airlines%7CMX_MCLA_MKT_Google_Brand_X_Mexico_National_ES_X$$&gad_source=1&gclid=Cj0KCQjwvb-zBhCmARIsAAfUI2tA1kC35ygd1ShwDBf-rMSX9F7nfO1ckMRtcopYsXKIyzmvVOfFwX8aAm3nEALw_wcB&gclsrc=aw.ds")

# Mes que queremos seleccionar
month = "noviembre 2025"

# Código original para seleccionar el mes
driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div/div/div[1]/div/div/div/div/label[1]").click()


mon = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/div[3]/div[2]/p")
while mon.text != month:
    # Captura de pantalla del mes seleccionado
    #driver.save_screenshot("mes_seleccionado.png")

    driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/button[2]/span").click()
    # Captura de pantalla después de avanzar el mes
    driver.save_screenshot("avanzar_mes.png")

# Espera para visualizar la pantalla antes de cerrar
#time.sleep(2)

# Cerrar el navegador al finalizar
driver.quit()

# %%
#el mero mero
#!pip install selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

# Configuración específica para Colab
chrome_options = Options()
chrome_options.add_argument('--headless')  # Ejecución sin interfaz gráfica
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Inicializar el driver de Selenium
driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.aa.com/es-mx/vuelos?c=SEM%7CGOOG%7Calways_on%7CMKT%7CLAM%7CTXT%7Camerican%20airlines%7CMX_MCLA_MKT_Google_Brand_X_Mexico_National_ES_X$$&gad_source=1&gclid=Cj0KCQjwvb-zBhCmARIsAAfUI2tA1kC35ygd1ShwDBf-rMSX9F7nfO1ckMRtcopYsXKIyzmvVOfFwX8aAm3nEALw_wcB&gclsrc=aw.ds")

# Mes que queremos seleccionar
month = "marzo 2025"
date = "28"

# Código original para seleccionar el mes
driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div/div/div[1]/div/div/div/div/label[1]").click()


mon = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/div[3]/div[2]/p")
while True:
    if mon.text == month:
    # Captura de pantalla del mes seleccionado
      driver.save_screenshot("mes_seleccionado.png")
      break
    else:
      driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/button[2]/span").click()
    # Captura de pantalla después de avanzar el mes
      driver.save_screenshot("avanzar_mes.png")

driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/div[3]/div[1]/div[2]/div/button[contains(text(),'"+date+"')]").click();
#/html/body/div[1]/div[2]/div[1]/div/div/div[2]/div/div/div/div/div/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div[1]/div[2]/div/div[2]/div[3]/div[1]/div[2]/div/button[19]
driver.save_screenshot("dia.png")
# Espera para visualizar la pantalla antes de cerrar
#time.sleep(2)

# Cerrar el navegador al finalizar
driver.quit()
