# %%
# Instalación de la biblioteca Appium-Python-Client en Google Colab
# !pip install Appium-Python-Client
# Importación de las bibliotecas necesarias
from appium import webdriver
from selenium.webdriver.common.by import By
import time

sauce_username = 'oauth-28cesarrosas-015ac'
sauce_access_key = '8ed9bc3d-859c-4ba9-a7d6-5ff93d66ad4e'

# Definición de las capacidades deseadas para la prueba en Sauce Labs
desired_caps = {
    'platformName': 'Android',
    'platformVersion': '10',
    'deviceName': 'Android Emulator',
    'app': 'sauce-storage:net.one97.paytm.apk',
    'name': 'Test on Sauce Labs'
}
# URL del servidor de Appium en Sauce Labs
#SAUCE_USERNAME = 'tu_usuario_de_sauce_labs'
#SAUCE_ACCESS_KEY = 'tu_access_key_de_sauce_labs'
sauce_url = f"http://{SAUCE_USERNAME}:{SAUCE_ACCESS_KEY}@ondemand.saucelabs.com:443/wd/hub"
# Inicialización del driver de Appium
driver = webdriver.Remote(sauce_url, desired_caps)
try:
    # Ejemplo de interacción con la aplicación móvil
    # Aquí puedes agregar los pasos específicos de prueba
    button = driver.find_element(By.ID, 'com.app.package:id/button')
    button.click()
    # Puedes agregar más pasos de prueba según sea necesario
    # Espera opcional para propósitos de demostración
    time.sleep(5)
finally:
    # Finalización de la prueba y cierre del driver
    if driver is not None:
        driver.quit()

#curl -u appautomator:581f76cf-114-40a7-88dc-7871e27dfcab \
#-X POST \
#-H "Content-Type: application/octet-stream" \
#https://saucelabs.com/rest/vl/storage/appautomator/test_file_name?overwrite true
#-data-binary @/path/to/your_file_name
